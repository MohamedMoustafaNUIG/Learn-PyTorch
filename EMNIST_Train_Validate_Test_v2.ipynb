# %%
print("Hello World")
# Out:
# Hello World

# %%
import torch
import numpy as np

# %%
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %%
#num of subprocesses to use for data loading
num_workers = 0
batch_size = 640
#validation percentage
valid_size = 0.2

# %%
transform = transforms.ToTensor()

train_data = datasets.EMNIST(root = 'EMNIST_data', 
                             split = 'byclass',
                             train=True,
                             download=False,
                             transform=transform)
test_data = datasets.EMNIST(root = 'EMNIST_data', 
                             split = 'byclass',
                             train=False,
                             download=False,
                             transform=transform)

# %%
#get indices for training and validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# %%
#define samplers for obtaining batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, 
                                           sampler = train_sampler, 
                                           num_workers = num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, 
                                           sampler = valid_sampler, 
                                           num_workers = num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size = batch_size,
                                           num_workers = num_workers)

# %% [markdown]
# <h2><b>Visualise data</b></h2>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#dict for number to letter
letters = {10:'A', 11:'B', 12:'C', 13:'D', 14:'E', 15:'F', 16:'G', 17:'H', 18:'I', 19:'J', 20:'K', 21:'L', 22:'M', 23:'N',
          24:'O', 25:'P', 26:'Q', 27:'R', 28:'S', 29:'T', 30:'U', 31:'V', 32:'W', 33:'X', 34:'Y', 35:'Z', 36:'a', 37:'b', 
           38:'c', 39:'d', 40:'e', 41:'f', 42:'g', 43:'h', 44:'i', 45:'j', 46:'k', 47:'k', 48:'m', 49:'n', 50:'o', 
           51:'p', 52:'q', 53:'r', 54:'s', 55:'t', 56:'u', 57:'v', 58:'w', 59:'x', 60:'y', 61:'z'}

#obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

fig = plt.figure(figsize=(25,4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title(str(labels[idx].item()) if labels[idx]<10 else letters[labels[idx].item()])

# %% [markdown]
# <h2><b>View image in more detail</b></h2>

# %%
img = np.squeeze(images[1])
print(img.shape)
fig = plt.figure(figsize = (12,12))
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')
width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        val = round(img[x][y].item(), 2) if img[x][y] != 0 else 0
        ax.annotate(str(val), xy=(y,x),
                   horizontalalignment = 'center',
                   verticalalignment = 'center',
                   color = 'white' if img[x][y]<thresh else 'black')
# Out:
# (28, 28)

# %% [markdown]
# <h2><b>Define Architecture</b></h2>

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        hidden_1 = 512
        hidden_2 = 512
        hidden_3 = 256
        hidden_4 = 256
        hidden_5 = 128
        drop = 0.2
        
        self.fc1 = nn.Linear(28*28, hidden_1)
        self.fc2 = nn.Linear(hidden_1, hidden_2)
        self.fc3 = nn.Linear(hidden_2, hidden_3)
        self.fc4 = nn.Linear(hidden_3, hidden_4)
        self.fc5 = nn.Linear(hidden_4, hidden_3)
        self.fc6 = nn.Linear(hidden_3, hidden_4)
        self.fc7 = nn.Linear(hidden_4, hidden_3)
        self.fc8 = nn.Linear(hidden_3, hidden_4)
        self.fc9 = nn.Linear(hidden_4, hidden_4)
        self.fc10 = nn.Linear(hidden_4, hidden_5)

        self.fc11 = nn.Linear(hidden_5, 62)
        self.dropout = nn.Dropout(drop)
        
    def forward(self, x):
        #flatten image
        x = x.view(-1, 28*28)
        
        x = F.leaky_relu(self.fc1(x))
        #x = self.dropout(x)
        
        x = F.leaky_relu(self.fc2(x))
        #x = self.dropout(x)
        
        x = F.leaky_relu(self.fc3(x))
        #x = self.dropout(x)
        
        x = F.leaky_relu(self.fc4(x))
        #x = self.dropout(x)
        
        x = F.leaky_relu(self.fc5(x))
        #x = self.dropout(x)

        x = F.leaky_relu(self.fc6(x))
        x = self.dropout(x)

        x = F.leaky_relu(self.fc7(x))
        x = self.dropout(x)

        x = F.leaky_relu(self.fc8(x))
        x = self.dropout(x)

        x = F.leaky_relu(self.fc9(x))
        x = self.dropout(x)

        x = F.leaky_relu(self.fc10(x))
        x = self.dropout(x)

        x = self.fc11(x)
        
        return x

model = Net()
print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=256, bias=True)
#   (fc5): Linear(in_features=256, out_features=256, bias=True)
#   (fc6): Linear(in_features=256, out_features=256, bias=True)
#   (fc7): Linear(in_features=256, out_features=256, bias=True)
#   (fc8): Linear(in_features=256, out_features=256, bias=True)
#   (fc9): Linear(in_features=256, out_features=256, bias=True)
#   (fc10): Linear(in_features=256, out_features=128, bias=True)
#   (fc11): Linear(in_features=128, out_features=62, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# <h2><b>Specify Loss and Optimization Functions</b></h2>

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.003)

# %% [markdown]
# <h2><b>Train Network</b></h2>

# %% [markdown]
# Steps:
# <ul>
# <li>Clear grads</li>
# <li>Forward prop</li>
# <li>Loss calc</li>
# <li>Back prop</li>
# <li>Optimization step</li>
# <li>Update average training loss</li>
# </ul>

# %%
epochs = 50
#init min validation loss
valid_loss_min = np.Inf
for epoch in range(epochs):
    batch_num=0

    train_loss = 0.0
    valid_loss = 0.0

    train_acc=0.0
    val_acc=0.0

    model.train()
    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_loss+=loss.item()*data.size(0)
        
        top_p, top_class = output.topk(1, dim=1)
        equals = top_class == target.view(*top_class.shape)
        train_acc += torch.mean(equals.type(torch.FloatTensor)).item()
        batch_num+=1

    model.eval()
    for data, target in valid_loader:
        output = model(data)
        loss = criterion(output, target)
        valid_loss+=loss.item()*data.size(0)

        top_p, top_class = output.topk(1, dim=1)
        equals = top_class == target.view(*top_class.shape)
        val_acc += torch.mean(equals.type(torch.FloatTensor)).item()
        
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1,
        train_loss,
        valid_loss
    ))
    
    print('Epoch: {} \tTraining Accuracy: {:.6f} \tValidation Accuracy: {:.6f}'.format(
        epoch+1,
        train_acc/batch_num * 100,
        val_acc/batch_num * 100
    ))

    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
        torch.save(model.state_dict(), 'modelEMNISTv3.pt')
        valid_loss_min = valid_loss
    print("")
# Out:
# Epoch: 1 	Training Loss: 1.350921 	Validation Loss: 0.765004
# Epoch: 1 	Training Accuracy: 61.330152 	Validation Accuracy: 19.297832
# Validation loss decreased (inf --> 0.765004).  Saving model ...
#
# Epoch: 2 	Training Loss: 0.715319 	Validation Loss: 0.629072
# Epoch: 2 	Training Accuracy: 78.749023 	Validation Accuracy: 20.158457
# Validation loss decreased (0.765004 --> 0.629072).  Saving model ...
#
# Epoch: 3 	Training Loss: 0.628894 	Validation Loss: 0.619228
# Epoch: 3 	Training Accuracy: 80.715225 	Validation Accuracy: 20.293300
# Validation loss decreased (0.629072 --> 0.619228).  Saving model ...
#
# Epoch: 4 	Training Loss: 0.605040 	Validation Loss: 0.587249
# Epoch: 4 	Training Accuracy: 81.260931 	Validation Accuracy: 20.396860
# Validation loss decreased (0.619228 --> 0.587249).  Saving model ...
#
# Epoch: 5 	Training Loss: 0.592717 	Validation Loss: 0.580799
# Epoch: 5 	Training Accuracy: 81.595664 	Validation Accuracy: 20.489143
# Validation loss decreased (0.587249 --> 0.580799).  Saving model ...
#
# Epoch: 6 	Training Loss: 0.575580 	Validation Loss: 0.562251
# Epoch: 6 	Training Accuracy: 81.901832 	Validation Accuracy: 20.576339
# Validation loss decreased (0.580799 --> 0.562251).  Saving model ...
#
# Epoch: 7 	Training Loss: 0.565225 	Validation Loss: 0.558431
# Epoch: 7 	Training Accuracy: 82.253467 	Validation Accuracy: 20.640810
# Validation loss decreased (0.562251 --> 0.558431).  Saving model ...
#
# Epoch: 8 	Training Loss: 0.555896 	Validation Loss: 0.551702
# Epoch: 8 	Training Accuracy: 82.489851 	Validation Accuracy: 20.621285
# Validation loss decreased (0.558431 --> 0.551702).  Saving model ...
#
# Epoch: 9 	Training Loss: 0.560131 	Validation Loss: 0.551250
# Epoch: 9 	Training Accuracy: 82.462265 	Validation Accuracy: 20.628189
# Validation loss decreased (0.551702 --> 0.551250).  Saving model ...
#
# Epoch: 10 	Training Loss: 0.544690 	Validation Loss: 0.530471
# Epoch: 10 	Training Accuracy: 82.827553 	Validation Accuracy: 20.825019
# Validation loss decreased (0.551250 --> 0.530471).  Saving model ...
#
# Epoch: 11 	Training Loss: 0.666351 	Validation Loss: 0.565263
# Epoch: 11 	Training Accuracy: 81.137591 	Validation Accuracy: 20.634280
#
# Epoch: 12 	Training Loss: 0.554787 	Validation Loss: 0.530977
# Epoch: 12 	Training Accuracy: 82.678081 	Validation Accuracy: 20.771786
#
# Epoch: 13 	Training Loss: 0.529745 	Validation Loss: 0.539425
# Epoch: 13 	Training Accuracy: 83.185341 	Validation Accuracy: 20.760922
#
# Epoch: 14 	Training Loss: 0.539969 	Validation Loss: 0.544968
# Epoch: 14 	Training Accuracy: 82.936077 	Validation Accuracy: 20.773847
#
# Epoch: 15 	Training Loss: 0.533362 	Validation Loss: 0.519886
# Epoch: 15 	Training Accuracy: 83.127709 	Validation Accuracy: 20.931973
# Validation loss decreased (0.530471 --> 0.519886).  Saving model ...
#
# Epoch: 16 	Training Loss: 0.522755 	Validation Loss: 0.521594
# Epoch: 16 	Training Accuracy: 83.421668 	Validation Accuracy: 20.895374
#
# Epoch: 17 	Training Loss: 0.531114 	Validation Loss: 0.607697
# Epoch: 17 	Training Accuracy: 83.247162 	Validation Accuracy: 20.841469
#
# Epoch: 18 	Training Loss: 0.628203 	Validation Loss: 0.544572
# Epoch: 18 	Training Accuracy: 81.226897 	Validation Accuracy: 20.771249
#
# Epoch: 19 	Training Loss: 0.535869 	Validation Loss: 0.523925
# Epoch: 19 	Training Accuracy: 83.099721 	Validation Accuracy: 20.780057
#
# Epoch: 20 	Training Loss: 0.661386 	Validation Loss: 1.758677
# Epoch: 20 	Training Accuracy: 81.410979 	Validation Accuracy: 19.730716
#
# Epoch: 21 	Training Loss: 0.706982 	Validation Loss: 0.630265
# Epoch: 21 	Training Accuracy: 79.582273 	Validation Accuracy: 20.244943
#
# Epoch: 22 	Training Loss: 0.572891 	Validation Loss: 0.524399
# Epoch: 22 	Training Accuracy: 82.259178 	Validation Accuracy: 20.864302
#
# Epoch: 23 	Training Loss: 0.521257 	Validation Loss: 0.513112
# Epoch: 23 	Training Accuracy: 83.311343 	Validation Accuracy: 20.868978
# Validation loss decreased (0.519886 --> 0.513112).  Saving model ...
#
# Epoch: 24 	Training Loss: 17.042839 	Validation Loss: 1.120314
# Epoch: 24 	Training Accuracy: 52.002791 	Validation Accuracy: 16.683719
#
# Epoch: 25 	Training Loss: 1.101350 	Validation Loss: 0.786226
# Epoch: 25 	Training Accuracy: 67.843746 	Validation Accuracy: 18.989004
#
# Epoch: 26 	Training Loss: 0.849100 	Validation Loss: 0.687032
# Epoch: 26 	Training Accuracy: 74.765907 	Validation Accuracy: 19.537411
#
# Epoch: 27 	Training Loss: 0.752112 	Validation Loss: 0.613497
# Epoch: 27 	Training Accuracy: 77.380265 	Validation Accuracy: 20.211935
#
# Epoch: 28 	Training Loss: 0.661364 	Validation Loss: 0.581382
# Epoch: 28 	Training Accuracy: 79.743327 	Validation Accuracy: 20.357126
#
# Epoch: 29 	Training Loss: 0.615101 	Validation Loss: 0.566591
# Epoch: 29 	Training Accuracy: 81.041574 	Validation Accuracy: 20.488877
#
# Epoch: 30 	Training Loss: 0.641805 	Validation Loss: 0.595949
# Epoch: 30 	Training Accuracy: 80.260341 	Validation Accuracy: 20.323960
#
# Epoch: 31 	Training Loss: 0.592774 	Validation Loss: 1.924077
# Epoch: 31 	Training Accuracy: 81.515016 	Validation Accuracy: 20.548315
#
# Epoch: 32 	Training Loss: 142.245421 	Validation Loss: 1.682816
# Epoch: 32 	Training Accuracy: 49.151756 	Validation Accuracy: 13.196055
#
# Epoch: 33 	Training Loss: 1.499897 	Validation Loss: 0.989618
# Epoch: 33 	Training Accuracy: 57.122495 	Validation Accuracy: 17.448535
#
# Epoch: 34 	Training Loss: 1.145902 	Validation Loss: 0.857304
# Epoch: 34 	Training Accuracy: 65.914426 	Validation Accuracy: 18.138131
#
# Epoch: 35 	Training Loss: 0.964387 	Validation Loss: 0.757920
# Epoch: 35 	Training Accuracy: 70.483888 	Validation Accuracy: 18.882077
#
# Epoch: 36 	Training Loss: 0.848718 	Validation Loss: 0.675645
# Epoch: 36 	Training Accuracy: 73.561072 	Validation Accuracy: 19.449055
#
# Epoch: 37 	Training Loss: 0.763840 	Validation Loss: 0.640238
# Epoch: 37 	Training Accuracy: 76.138789 	Validation Accuracy: 19.859348
#
# Epoch: 38 	Training Loss: 0.708739 	Validation Loss: 0.612358
# Epoch: 38 	Training Accuracy: 78.084055 	Validation Accuracy: 20.197264
#
# Epoch: 39 	Training Loss: 0.681702 	Validation Loss: 0.585974
# Epoch: 39 	Training Accuracy: 78.976066 	Validation Accuracy: 20.281417
#
# Epoch: 40 	Training Loss: 0.652328 	Validation Loss: 0.576654
# Epoch: 40 	Training Accuracy: 79.761091 	Validation Accuracy: 20.453580
#
# Epoch: 41 	Training Loss: 0.609822 	Validation Loss: 0.547257
# Epoch: 41 	Training Accuracy: 80.896968 	Validation Accuracy: 20.619620
#
# Epoch: 42 	Training Loss: 2020055.800928 	Validation Loss: 3.831187
# Epoch: 42 	Training Accuracy: 17.329699 	Validation Accuracy: 3.136737
#
# Epoch: 43 	Training Loss: 3.904229 	Validation Loss: 3.421765
# Epoch: 43 	Training Accuracy: 10.451421 	Validation Accuracy: 3.308737
#
# Epoch: 44 	Training Loss: 3.335314 	Validation Loss: 3.020212
# Epoch: 44 	Training Accuracy: 16.088027 	Validation Accuracy: 5.443899
#
# Epoch: 45 	Training Loss: 3.102679 	Validation Loss: 2.946170
# Epoch: 45 	Training Accuracy: 19.514189 	Validation Accuracy: 5.806085
#
# Epoch: 46 	Training Loss: 2.904506 	Validation Loss: 2.537535
# Epoch: 46 	Training Accuracy: 23.868314 	Validation Accuracy: 7.970887
#
# Epoch: 47 	Training Loss: 2.645356 	Validation Loss: 2.420133
# Epoch: 47 	Training Accuracy: 29.185367 	Validation Accuracy: 8.835075
#
# Epoch: 48 	Training Loss: 2.402503 	Validation Loss: 2.062221
# Epoch: 48 	Training Accuracy: 34.122460 	Validation Accuracy: 10.058049
#
# Epoch: 49 	Training Loss: 2.198497 	Validation Loss: 2.151822
# Epoch: 49 	Training Accuracy: 38.818367 	Validation Accuracy: 10.459698
#
# Epoch: 50 	Training Loss: 2.023694 	Validation Loss: 1.663480
# Epoch: 50 	Training Accuracy: 42.982689 	Validation Accuracy: 12.998390

# %%
model.load_state_dict(torch.load('modelEMNISTv3.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# <h2><b>Test the Trained Network</b></h2>

# %%
test_loss = 0.0
class_correct = list(0. for i in range (62))
class_total = list(0. for i in range (62))

model.eval()

for data, target in test_loader:
    output = model(data)
    loss = criterion(output, target)
    test_loss += loss.item()*data.size(0)
    _, pred = torch.max(output, 1)
    #compare pred to label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1
        
test_loss = test_loss/len(test_loader.sampler)
print('Test Loss: {:.6}\n'.format(test_loss))

for i in range(62):
    if class_total[i] > 0:
      if (100*class_correct[i]/class_total[i] < 50):
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            str(i) if i<10 else letters[i],
            100*class_correct[i]/class_total[i],
            np.sum(class_correct[i]),
            np.sum(class_total[i]))
        )
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. *np.sum(class_correct)/np.sum(class_total),
    np.sum(class_correct),
    np.sum(class_total))
     )
# Out:
# Test Loss: 5.48295
#
# Test Accuracy of     O: 33% (1412/4156)
# Test Accuracy of     c:  0% ( 0/432)
# Test Accuracy of     f:  0% ( 0/400)
# Test Accuracy of     g: 28% (170/589)
# Test Accuracy of     i: 33% (144/427)
# Test Accuracy of     j: 43% (139/317)
# Test Accuracy of     k: 34% (159/466)
# Test Accuracy of     k:  0% ( 1/2535)
# Test Accuracy of     m:  0% ( 0/464)
# Test Accuracy of     o:  0% ( 0/466)
# Test Accuracy of     p:  0% ( 0/368)
# Test Accuracy of     q: 28% (143/505)
# Test Accuracy of     s:  0% ( 0/437)
# Test Accuracy of     u:  0% ( 0/482)
# Test Accuracy of     v:  0% ( 0/468)
# Test Accuracy of     x: 32% (155/470)
# Test Accuracy of     y:  0% ( 0/381)
# Test Accuracy of     z: 23% (107/451)
#
# Test Accuracy (Overall): 83% (97012/116323)

# %% [markdown]
# <h2><b>Visualize Sample test Results</b></h2>

# %%
dataiter = iter(test_loader)
images , labels = dataiter.next()

output = model(images)
_, preds = torch.max(output, 1)
images = images.numpy()

fig = plt.figure(figsize=(25,4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(
        str(str(preds[idx].item()) if preds[idx]<10 else letters[preds[idx].item()]),
        str(str(labels[idx].item()) if labels[idx]<10 else letters[labels[idx].item()])), 
        color = ("green" if preds[idx] == labels[idx] else "red"))
